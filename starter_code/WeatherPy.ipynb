# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
   
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | matagami
# Processing Record 3 of Set 1 | tiznit
# Processing Record 4 of Set 1 | katsuura
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | rio grande
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | waterloo
# Processing Record 12 of Set 1 | kenai
# Processing Record 13 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | nioro
# Processing Record 16 of Set 1 | arkhangelskoye
# Processing Record 17 of Set 1 | pundaguitan
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | zaysan
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | ozernovskiy
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | klaksvik
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | kamina
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | necochea
# Processing Record 29 of Set 1 | leh
# Processing Record 30 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | tual
# Processing Record 33 of Set 1 | birin
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | bethel
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | adeje
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | atambua
# Processing Record 42 of Set 1 | hami
# Processing Record 43 of Set 1 | mosquera
# Processing Record 44 of Set 1 | severo-kurilsk
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | alamogordo
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | split
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | tessalit
# Processing Record 0 of Set 2 | kavieng
# Processing Record 1 of Set 2 | pekan
# Processing Record 2 of Set 2 | east london
# Processing Record 3 of Set 2 | kardla
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 6 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 2 | adrar
# Processing Record 8 of Set 2 | taoudenni
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | sumenep
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | tarauaca
# Processing Record 14 of Set 2 | bredasdorp
# Processing Record 15 of Set 2 | mandalgovi
# Processing Record 16 of Set 2 | port moresby
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | les escoumins
# Processing Record 20 of Set 2 | kiama
# Processing Record 21 of Set 2 | cacapava do sul
# Processing Record 22 of Set 2 | saint andrews
# Processing Record 23 of Set 2 | dikson
# Processing Record 24 of Set 2 | yima
# Processing Record 25 of Set 2 | bonfim
# Processing Record 26 of Set 2 | memari
# Processing Record 27 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 2 | sahrak
# City not found. Skipping...
# Processing Record 29 of Set 2 | san pedro de tutule
# Processing Record 30 of Set 2 | sitka
# Processing Record 31 of Set 2 | gat
# Processing Record 32 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 2 | araouane
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | taburao
# City not found. Skipping...
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | hobart
# Processing Record 38 of Set 2 | mar del plata
# Processing Record 39 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 2 | sento se
# City not found. Skipping...
# Processing Record 41 of Set 2 | port macquarie
# Processing Record 42 of Set 2 | port alfred
# Processing Record 43 of Set 2 | atuona
# Processing Record 44 of Set 2 | khatanga
# Processing Record 45 of Set 2 | balta
# Processing Record 46 of Set 2 | moose factory
# Processing Record 47 of Set 2 | botou
# Processing Record 48 of Set 2 | port hedland
# Processing Record 49 of Set 2 | tasiilaq
# Processing Record 0 of Set 3 | lavrentiya
# Processing Record 1 of Set 3 | acapulco
# Processing Record 2 of Set 3 | saint-pierre
# Processing Record 3 of Set 3 | airai
# Processing Record 4 of Set 3 | narsaq
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | saldanha
# Processing Record 7 of Set 3 | ternate
# Processing Record 8 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 3 | izhma
# Processing Record 10 of Set 3 | cape town
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | makung
# City not found. Skipping...
# Processing Record 13 of Set 3 | coquimbo
# Processing Record 14 of Set 3 | gradignan
# Processing Record 15 of Set 3 | saint george
# Processing Record 16 of Set 3 | nelson bay
# Processing Record 17 of Set 3 | krasnoselkup
# Processing Record 18 of Set 3 | coracora
# Processing Record 19 of Set 3 | anloga
# Processing Record 20 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 3 | beringovskiy
# Processing Record 22 of Set 3 | hambantota
# Processing Record 23 of Set 3 | egvekinot
# Processing Record 24 of Set 3 | kieta
# Processing Record 25 of Set 3 | luau
# Processing Record 26 of Set 3 | souillac
# Processing Record 27 of Set 3 | mazatlan
# Processing Record 28 of Set 3 | nanortalik
# Processing Record 29 of Set 3 | ponta do sol
# Processing Record 30 of Set 3 | makueni
# Processing Record 31 of Set 3 | marawi
# Processing Record 32 of Set 3 | dingle
# Processing Record 33 of Set 3 | haines junction
# Processing Record 34 of Set 3 | rabo de peixe
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | mathbaria
# Processing Record 37 of Set 3 | camacha
# Processing Record 38 of Set 3 | mecca
# Processing Record 39 of Set 3 | maniitsoq
# Processing Record 40 of Set 3 | torbay
# Processing Record 41 of Set 3 | mahebourg
# Processing Record 42 of Set 3 | hithadhoo
# Processing Record 43 of Set 3 | dunedin
# Processing Record 44 of Set 3 | calbuco
# Processing Record 45 of Set 3 | puerto ayora
# Processing Record 46 of Set 3 | turukhansk
# Processing Record 47 of Set 3 | chimbote
# Processing Record 48 of Set 3 | lorengau
# Processing Record 49 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 0 of Set 4 | srandakan
# Processing Record 1 of Set 4 | kumbo
# Processing Record 2 of Set 4 | meulaboh
# Processing Record 3 of Set 4 | manokwari
# Processing Record 4 of Set 4 | te anau
# Processing Record 5 of Set 4 | kapaa
# Processing Record 6 of Set 4 | bloomfield
# Processing Record 7 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 4 | medowie
# Processing Record 9 of Set 4 | slave lake
# Processing Record 10 of Set 4 | dhidhdhoo
# Processing Record 11 of Set 4 | oranjemund
# Processing Record 12 of Set 4 | batemans bay
# Processing Record 13 of Set 4 | borodino
# Processing Record 14 of Set 4 | ishigaki
# Processing Record 15 of Set 4 | daru
# Processing Record 16 of Set 4 | leshukonskoye
# Processing Record 17 of Set 4 | jarjis
# City not found. Skipping...
# Processing Record 18 of Set 4 | cayenne
# Processing Record 19 of Set 4 | sampit
# Processing Record 20 of Set 4 | saint-philippe
# Processing Record 21 of Set 4 | longyearbyen
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | mayo
# Processing Record 24 of Set 4 | san patricio
# Processing Record 25 of Set 4 | paso de los toros
# Processing Record 26 of Set 4 | megion
# Processing Record 27 of Set 4 | cherlak
# Processing Record 28 of Set 4 | iqaluit
# Processing Record 29 of Set 4 | codrington
# Processing Record 30 of Set 4 | roseburg
# Processing Record 31 of Set 4 | gaoua
# Processing Record 32 of Set 4 | upernavik
# Processing Record 33 of Set 4 | boone
# Processing Record 34 of Set 4 | carnarvon
# Processing Record 35 of Set 4 | kualakapuas
# Processing Record 36 of Set 4 | sovetskiy
# Processing Record 37 of Set 4 | kaabong
# Processing Record 38 of Set 4 | punakha
# Processing Record 39 of Set 4 | bella vista
# Processing Record 40 of Set 4 | eyl
# Processing Record 41 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 4 | tigil
# Processing Record 43 of Set 4 | abu samrah
# Processing Record 44 of Set 4 | chulumani
# Processing Record 45 of Set 4 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 46 of Set 4 | kirkuk
# Processing Record 47 of Set 4 | santa rosa
# Processing Record 48 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 4 | tiksi
# Processing Record 0 of Set 5 | guerrero negro
# Processing Record 1 of Set 5 | vestmannaeyjar
# Processing Record 2 of Set 5 | balakhonovskoye
# Processing Record 3 of Set 5 | tortoli
# Processing Record 4 of Set 5 | dutse
# Processing Record 5 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 5 | malangali
# Processing Record 7 of Set 5 | richards bay
# Processing Record 8 of Set 5 | sawang daen din
# Processing Record 9 of Set 5 | kaitangata
# Processing Record 10 of Set 5 | saint-francois
# Processing Record 11 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 5 | naze
# Processing Record 13 of Set 5 | hamilton
# Processing Record 14 of Set 5 | aykhal
# Processing Record 15 of Set 5 | vysha
# Processing Record 16 of Set 5 | muborak
# Processing Record 17 of Set 5 | nyrob
# Processing Record 18 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 5 | teya
# Processing Record 20 of Set 5 | freeport
# Processing Record 21 of Set 5 | san rafael
# Processing Record 22 of Set 5 | broken hill
# Processing Record 23 of Set 5 | sur
# Processing Record 24 of Set 5 | ustye
# Processing Record 25 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 5 | bambanglipuro
# Processing Record 27 of Set 5 | faanui
# Processing Record 28 of Set 5 | novo aripuana
# Processing Record 29 of Set 5 | sinnamary
# Processing Record 30 of Set 5 | bani
# Processing Record 31 of Set 5 | sioux lookout
# Processing Record 32 of Set 5 | kruisfontein
# Processing Record 33 of Set 5 | sabaudia
# Processing Record 34 of Set 5 | tamandare
# Processing Record 35 of Set 5 | agadez
# Processing Record 36 of Set 5 | chuy
# Processing Record 37 of Set 5 | geraldton
# Processing Record 38 of Set 5 | turka
# Processing Record 39 of Set 5 | deputatskiy
# Processing Record 40 of Set 5 | yefimovskiy
# City not found. Skipping...
# Processing Record 41 of Set 5 | flinders
# Processing Record 42 of Set 5 | caruray
# Processing Record 43 of Set 5 | victoria
# Processing Record 44 of Set 5 | ponnani
# Processing Record 45 of Set 5 | cachoeira do sul
# Processing Record 46 of Set 5 | axim
# Processing Record 47 of Set 5 | half moon bay
# Processing Record 48 of Set 5 | shihezi
# Processing Record 49 of Set 5 | pangnirtung
# Processing Record 0 of Set 6 | bhuban
# Processing Record 1 of Set 6 | pasni
# Processing Record 2 of Set 6 | pevek
# Processing Record 3 of Set 6 | naliya
# Processing Record 4 of Set 6 | marsa matruh
# Processing Record 5 of Set 6 | provideniya
# Processing Record 6 of Set 6 | atar
# Processing Record 7 of Set 6 | tura
# Processing Record 8 of Set 6 | diffa
# Processing Record 9 of Set 6 | sao filipe
# Processing Record 10 of Set 6 | nantucket
# Processing Record 11 of Set 6 | sept-iles
# Processing Record 12 of Set 6 | isangel
# Processing Record 13 of Set 6 | bubaque
# Processing Record 14 of Set 6 | biak
# Processing Record 15 of Set 6 | zhaoyuan
# Processing Record 16 of Set 6 | san buenaventura
# Processing Record 17 of Set 6 | mount isa
# Processing Record 18 of Set 6 | yarmouth
# Processing Record 19 of Set 6 | alofi
# Processing Record 20 of Set 6 | wagar
# Processing Record 21 of Set 6 | cidreira
# Processing Record 22 of Set 6 | laguna
# Processing Record 23 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 6 | martapura
# Processing Record 25 of Set 6 | mujiayingzi
# Processing Record 26 of Set 6 | almoradi
# Processing Record 27 of Set 6 | stolnici
# Processing Record 28 of Set 6 | batagay-alyta
# Processing Record 29 of Set 6 | sinazongwe
# Processing Record 30 of Set 6 | kiunga
# Processing Record 31 of Set 6 | nishihara
# Processing Record 32 of Set 6 | havre-saint-pierre
# Processing Record 33 of Set 6 | mashhad
# Processing Record 34 of Set 6 | cape coast
# Processing Record 35 of Set 6 | valparaiso
# Processing Record 36 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 37 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 6 | leningradskiy
# Processing Record 39 of Set 6 | boca do acre
# Processing Record 40 of Set 6 | kropotkin
# Processing Record 41 of Set 6 | itacarambi
# Processing Record 42 of Set 6 | amuntai
# Processing Record 43 of Set 6 | nusaybin
# Processing Record 44 of Set 6 | hit
# Processing Record 45 of Set 6 | banswara
# Processing Record 46 of Set 6 | evensk
# Processing Record 47 of Set 6 | manggar
# Processing Record 48 of Set 6 | tokat
# Processing Record 49 of Set 6 | huancavelica
# Processing Record 0 of Set 7 | gizo
# Processing Record 1 of Set 7 | chapais
# Processing Record 2 of Set 7 | ancud
# Processing Record 3 of Set 7 | nikolskoye
# Processing Record 4 of Set 7 | pesochnyy
# Processing Record 5 of Set 7 | esperance
# Processing Record 6 of Set 7 | russellville
# Processing Record 7 of Set 7 | markova
# Processing Record 8 of Set 7 | westport
# Processing Record 9 of Set 7 | pietersburg
# Processing Record 10 of Set 7 | marienburg
# Processing Record 11 of Set 7 | ahipara
# Processing Record 12 of Set 7 | cap malheureux
# Processing Record 13 of Set 7 | vardo
# Processing Record 14 of Set 7 | beyla
# Processing Record 15 of Set 7 | bathsheba
# Processing Record 16 of Set 7 | ankazobe
# Processing Record 17 of Set 7 | shache
# Processing Record 18 of Set 7 | bardiyah
# Processing Record 19 of Set 7 | pokhara
# Processing Record 20 of Set 7 | puerto baquerizo moreno
# Processing Record 21 of Set 7 | zhigansk
# Processing Record 22 of Set 7 | acarau
# Processing Record 23 of Set 7 | lasa
# Processing Record 24 of Set 7 | novikovo
# Processing Record 25 of Set 7 | nakuru
# Processing Record 26 of Set 7 | cianorte
# Processing Record 27 of Set 7 | lukovetskiy
# Processing Record 28 of Set 7 | otradnoye
# Processing Record 29 of Set 7 | langxiang
# Processing Record 30 of Set 7 | ilulissat
# Processing Record 31 of Set 7 | san mateo del mar
# Processing Record 32 of Set 7 | stokmarknes
# Processing Record 33 of Set 7 | bowen
# Processing Record 34 of Set 7 | san vicente
# Processing Record 35 of Set 7 | san jose
# Processing Record 36 of Set 7 | imeni poliny osipenko
# Processing Record 37 of Set 7 | ahuimanu
# Processing Record 38 of Set 7 | pala
# Processing Record 39 of Set 7 | nuevo progreso
# Processing Record 40 of Set 7 | broome
# Processing Record 41 of Set 7 | camopi
# Processing Record 42 of Set 7 | morehead
# Processing Record 43 of Set 7 | kahului
# Processing Record 44 of Set 7 | salaga
# Processing Record 45 of Set 7 | carauari
# Processing Record 46 of Set 7 | nome
# Processing Record 47 of Set 7 | rawson
# Processing Record 48 of Set 7 | mahon
# Processing Record 49 of Set 7 | la ronge
# Processing Record 0 of Set 8 | antofagasta
# Processing Record 1 of Set 8 | canon city
# Processing Record 2 of Set 8 | lerwick
# Processing Record 3 of Set 8 | rundu
# Processing Record 4 of Set 8 | henties bay
# Processing Record 5 of Set 8 | saravan
# Processing Record 6 of Set 8 | thinadhoo
# Processing Record 7 of Set 8 | suclayin
# Processing Record 8 of Set 8 | bandarbeyla
# Processing Record 9 of Set 8 | paracatu
# Processing Record 10 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 8 | fort nelson
# Processing Record 12 of Set 8 | labuhan
# Processing Record 13 of Set 8 | jabiru
# City not found. Skipping...
# Processing Record 14 of Set 8 | port lincoln
# Processing Record 15 of Set 8 | rahon
# Processing Record 16 of Set 8 | rantauprapat
# Processing Record 17 of Set 8 | ilebo
# Processing Record 18 of Set 8 | aguimes
# Processing Record 19 of Set 8 | tezu
# Processing Record 20 of Set 8 | san lawrenz
# Processing Record 21 of Set 8 | carballo
# Processing Record 22 of Set 8 | comodoro rivadavia
# Processing Record 23 of Set 8 | talnakh
# Processing Record 24 of Set 8 | roald
# Processing Record 25 of Set 8 | beidao
# Processing Record 26 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 8 | roma
# Processing Record 28 of Set 8 | tahoua
# Processing Record 29 of Set 8 | mendahara
# City not found. Skipping...
# Processing Record 30 of Set 8 | svetlogorsk
# Processing Record 31 of Set 8 | havelock
# Processing Record 32 of Set 8 | kamenka
# Processing Record 33 of Set 8 | tete
# Processing Record 34 of Set 8 | bayanday
# Processing Record 35 of Set 8 | lagoa
# Processing Record 36 of Set 8 | tuatapere
# Processing Record 37 of Set 8 | winnemucca
# Processing Record 38 of Set 8 | bac lieu
# Processing Record 39 of Set 8 | altay
# Processing Record 40 of Set 8 | yago
# Processing Record 41 of Set 8 | los llanos de aridane
# Processing Record 42 of Set 8 | maniwaki
# Processing Record 43 of Set 8 | kuching
# Processing Record 44 of Set 8 | ye
# City not found. Skipping...
# Processing Record 45 of Set 8 | redlands
# Processing Record 46 of Set 8 | wasilla
# Processing Record 47 of Set 8 | tucuman
# Processing Record 48 of Set 8 | the hammocks
# Processing Record 49 of Set 8 | mehamn
# Processing Record 0 of Set 9 | shimoda
# Processing Record 1 of Set 9 | singleton
# Processing Record 2 of Set 9 | fairbanks
# Processing Record 3 of Set 9 | norman wells
# Processing Record 4 of Set 9 | ukiah
# Processing Record 5 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 9 | srednekolymsk
# Processing Record 7 of Set 9 | chipinge
# Processing Record 8 of Set 9 | oussouye
# Processing Record 9 of Set 9 | kokstad
# Processing Record 10 of Set 9 | dyersburg
# Processing Record 11 of Set 9 | janakkala
# Processing Record 12 of Set 9 | laramie
# Processing Record 13 of Set 9 | cody
# Processing Record 14 of Set 9 | boa vista
# Processing Record 15 of Set 9 | nouadhibou
# Processing Record 16 of Set 9 | wanaka
# Processing Record 17 of Set 9 | jumla
# Processing Record 18 of Set 9 | shenzhen
# Processing Record 19 of Set 9 | muisne
# Processing Record 20 of Set 9 | clovis
# Processing Record 21 of Set 9 | vanimo
# Processing Record 22 of Set 9 | morant bay
# Processing Record 23 of Set 9 | lahij
# Processing Record 24 of Set 9 | krizevci
# Processing Record 25 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 26 of Set 9 | lazaro cardenas
# Processing Record 27 of Set 9 | umea
# Processing Record 28 of Set 9 | palu
# Processing Record 29 of Set 9 | sabha
# Processing Record 30 of Set 9 | chipoka
# Processing Record 31 of Set 9 | albanel
# Processing Record 32 of Set 9 | sechura
# Processing Record 33 of Set 9 | kalmunai
# Processing Record 34 of Set 9 | fortuna
# Processing Record 35 of Set 9 | novyy urengoy
# Processing Record 36 of Set 9 | goderich
# Processing Record 37 of Set 9 | salalah
# Processing Record 38 of Set 9 | saint-georges
# Processing Record 39 of Set 9 | waipawa
# Processing Record 40 of Set 9 | itoman
# Processing Record 41 of Set 9 | saint-michel-des-saints
# Processing Record 42 of Set 9 | bambous virieux
# Processing Record 43 of Set 9 | rocha
# Processing Record 44 of Set 9 | anklam
# Processing Record 45 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 46 of Set 9 | rio cuarto
# Processing Record 47 of Set 9 | itarema
# Processing Record 48 of Set 9 | stornoway
# Processing Record 49 of Set 9 | powell river
# Processing Record 0 of Set 10 | praya
# Processing Record 1 of Set 10 | ljubuski
# Processing Record 2 of Set 10 | springfield
# Processing Record 3 of Set 10 | bjornevatn
# Processing Record 4 of Set 10 | maketu
# Processing Record 5 of Set 10 | olafsvik
# Processing Record 6 of Set 10 | majene
# Processing Record 7 of Set 10 | gaya
# Processing Record 8 of Set 10 | sangmelima
# Processing Record 9 of Set 10 | sorland
# Processing Record 10 of Set 10 | padang
# Processing Record 11 of Set 10 | grindavik
# Processing Record 12 of Set 10 | alytus
# Processing Record 13 of Set 10 | kralendijk
# Processing Record 14 of Set 10 | aplahoue
# Processing Record 15 of Set 10 | clyde river
# Processing Record 16 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 10 | tigre
# Processing Record 18 of Set 10 | fairmont
# Processing Record 19 of Set 10 | pereira barreto
# Processing Record 20 of Set 10 | sanming
# Processing Record 21 of Set 10 | makakilo city
# Processing Record 22 of Set 10 | sobolevo
# Processing Record 23 of Set 10 | wanning
# Processing Record 24 of Set 10 | talcahuano
# Processing Record 25 of Set 10 | kihei
# Processing Record 26 of Set 10 | yumen
# Processing Record 27 of Set 10 | lompoc
# Processing Record 28 of Set 10 | vadso
# Processing Record 29 of Set 10 | kumi
# Processing Record 30 of Set 10 | sao luiz gonzaga
# Processing Record 31 of Set 10 | portobelo
# Processing Record 32 of Set 10 | gazli
# Processing Record 33 of Set 10 | cortez
# Processing Record 34 of Set 10 | cairo montenotte
# Processing Record 35 of Set 10 | vryburg
# Processing Record 36 of Set 10 | sar-e pul
# Processing Record 37 of Set 10 | namatanai
# Processing Record 38 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 10 | karaton
# Processing Record 40 of Set 10 | solanea
# Processing Record 41 of Set 10 | effingham
# Processing Record 42 of Set 10 | chara
# Processing Record 43 of Set 10 | mazyr
# Processing Record 44 of Set 10 | kavaratti
# Processing Record 45 of Set 10 | doba
# Processing Record 46 of Set 10 | gondar
# Processing Record 47 of Set 10 | polunochnoye
# Processing Record 48 of Set 10 | winslow
# Processing Record 49 of Set 10 | loa janan
# Processing Record 0 of Set 11 | san agustin acasaguastlan
# Processing Record 1 of Set 11 | kannangad
# Processing Record 2 of Set 11 | qeshm
# Processing Record 3 of Set 11 | lima
# Processing Record 4 of Set 11 | dankov
# Processing Record 5 of Set 11 | luderitz
# Processing Record 6 of Set 11 | alta floresta
# Processing Record 7 of Set 11 | tucumcari
# Processing Record 8 of Set 11 | marinette
# Processing Record 9 of Set 11 | pinerolo
# Processing Record 10 of Set 11 | charlton
# Processing Record 11 of Set 11 | tabarqah
# City not found. Skipping...
# Processing Record 12 of Set 11 | fairlie
# Processing Record 13 of Set 11 | wodonga
# Processing Record 14 of Set 11 | bilibino
# Processing Record 15 of Set 11 | bonavista
# Processing Record 16 of Set 11 | coihaique
# Processing Record 17 of Set 11 | qaqortoq
# Processing Record 18 of Set 11 | qasigiannguit
# Processing Record 19 of Set 11 | pinhao
# Processing Record 20 of Set 11 | devarkonda
# Processing Record 21 of Set 11 | strezhevoy
# Processing Record 22 of Set 11 | belaya gora
# Processing Record 23 of Set 11 | elat
# Processing Record 24 of Set 11 | berlevag
# Processing Record 25 of Set 11 | poum
# Processing Record 26 of Set 11 | piacabucu
# Processing Record 27 of Set 11 | praia da vitoria
# Processing Record 28 of Set 11 | santiago de cao
# Processing Record 29 of Set 11 | yeletskiy
# City not found. Skipping...
# Processing Record 30 of Set 11 | khanpur
# Processing Record 31 of Set 11 | nara
# Processing Record 32 of Set 11 | skovorodino
# Processing Record 33 of Set 11 | mansa
# Processing Record 34 of Set 11 | berdigestyakh
# Processing Record 35 of Set 11 | kholtoson
# Processing Record 36 of Set 11 | mildura
# Processing Record 37 of Set 11 | aktash
# Processing Record 38 of Set 11 | matara
# Processing Record 39 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 11 | hohhot
# Processing Record 41 of Set 11 | inirida
# Processing Record 42 of Set 11 | hasaki
# Processing Record 43 of Set 11 | lake wales
# Processing Record 44 of Set 11 | yulara
# Processing Record 45 of Set 11 | amapa
# Processing Record 46 of Set 11 | baruun-urt
# Processing Record 47 of Set 11 | husavik
# Processing Record 48 of Set 11 | nago
# Processing Record 49 of Set 11 | lata
# Processing Record 0 of Set 12 | takoradi
# Processing Record 1 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 2 of Set 12 | namibe
# Processing Record 3 of Set 12 | alice springs
# Processing Record 4 of Set 12 | svetlyy
# Processing Record 5 of Set 12 | selaphum
# Processing Record 6 of Set 12 | medicine hat
# Processing Record 7 of Set 12 | pisco
# Processing Record 8 of Set 12 | tashara
# Processing Record 9 of Set 12 | kimberley
# Processing Record 10 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 11 of Set 12 | walvis bay
# Processing Record 12 of Set 12 | neiafu
# Processing Record 13 of Set 12 | arlit
# Processing Record 14 of Set 12 | pozo colorado
# Processing Record 15 of Set 12 | dhandhuka
# Processing Record 16 of Set 12 | tavda
# Processing Record 17 of Set 12 | bongaree
# Processing Record 18 of Set 12 | dangriga
# Processing Record 19 of Set 12 | ratholo
# Processing Record 20 of Set 12 | port pirie
# Processing Record 21 of Set 12 | inuvik
# Processing Record 22 of Set 12 | plover
# Processing Record 23 of Set 12 | korcula
# Processing Record 24 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 25 of Set 12 | kushiro
# Processing Record 26 of Set 12 | astoria
# Processing Record 27 of Set 12 | khani
# Processing Record 28 of Set 12 | nouakchott
# Processing Record 29 of Set 12 | cabo san lucas
# Processing Record 30 of Set 12 | kolondieba
# Processing Record 31 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 32 of Set 12 | kingaroy
# Processing Record 33 of Set 12 | saint anthony
# Processing Record 34 of Set 12 | honiara
# Processing Record 35 of Set 12 | rongcheng
# Processing Record 36 of Set 12 | llanes
# Processing Record 37 of Set 12 | bangassou
# Processing Record 38 of Set 12 | lakes entrance
# Processing Record 39 of Set 12 | newport
# Processing Record 40 of Set 12 | beloha
# Processing Record 41 of Set 12 | anadyr
# Processing Record 42 of Set 12 | naifaru
# Processing Record 43 of Set 12 | puerto rondon
# Processing Record 44 of Set 12 | celestun
# Processing Record 45 of Set 12 | toftir
# City not found. Skipping...
# Processing Record 46 of Set 12 | prince rupert
# Processing Record 47 of Set 12 | ekhabi
# Processing Record 48 of Set 12 | sault sainte marie
# Processing Record 49 of Set 12 | san matias
# Processing Record 0 of Set 13 | tupik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          552
# Lat           552
# Lng           552
# Max Temp      552
# Humidity      552
# Cloudiness    552
# Wind Speed    552
# Country       552
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     bluff -46.6000  168.3333     15.45        70          11        2.89
# 1  matagami  49.7502  -77.6328    -17.94        65           0        2.06
# 2    tiznit  29.5833   -9.5000     12.19        63           0        2.64
# 3  katsuura  35.1333  140.3000      9.25        67           2        2.30
# 4   rikitea -23.1203 -134.9692     26.71        74           8        6.67
#
#   Country
# 0      NZ
# 1      CA
# 2      MA
# 3      JP
# 4      PF

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           bluff -46.6000  168.3333     15.45        70          11
# 1        matagami  49.7502  -77.6328    -17.94        65           0
# 2          tiznit  29.5833   -9.5000     12.19        63           0
# 3        katsuura  35.1333  140.3000      9.25        67           2
# 4         rikitea -23.1203 -134.9692     26.71        74           8
#
#          Wind Speed Country
# City_ID
# 0              2.89      NZ
# 1              2.06      CA
# 2              2.64      MA
# 3              2.30      JP
# 4              6.67      PF

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'])

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'])

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Humidity (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)


# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'])

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Cloudiness (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)


# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'])

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Wind Speed (%s)" % time.strftime("%Y-%m-%d"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)


# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear(x_values, y_values, title, text_coordinates):
    

    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        matagami  49.7502  -77.6328    -17.94        65           0
# 2          tiznit  29.5833   -9.5000     12.19        63           0
# 3        katsuura  35.1333  140.3000      9.25        67           2
# 8        waterloo  43.4668  -80.5164     -7.37        87         100
# 9           kenai  60.5544 -151.2583     -1.06        87         100
#
#          Wind Speed Country
# City_ID
# 1              2.06      CA
# 2              2.64      MA
# 3              2.30      JP
# 8              6.69      CA
# 9              5.14      US

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               bluff -46.6000  168.3333     15.45        70          11
# 4             rikitea -23.1203 -134.9692     26.71        74           8
# 5        punta arenas -53.1500  -70.9167     11.06        76          75
# 6          rio grande -32.0350  -52.0986     20.06        30           4
# 7               vaini -21.2000 -175.2000     26.09        94          75
#
#          Wind Speed Country
# City_ID
# 0              2.89      NZ
# 4              6.67      PF
# 5              3.60      CL
# 6              7.58      BR
# 7              5.14      TO

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x=northern_hemi_df["Lat"]
y=northern_hemi_df["Max Temp"]
title = "Lat vs Max Temp"

linear(x,y,title,(6,-30))
# Out:
# The r-value is: 0.7308137214401261

# %%
# Linear regression on Southern Hemisphere
x=southern_hemi_df["Lat"]
y=southern_hemi_df["Max Temp"]
title = "Lat vs Max Temp"

linear(x,y,title,(-40,5))
# Out:
# The r-value is: 0.23699295012632013

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x=northern_hemi_df["Lat"]
y=northern_hemi_df["Humidity"]
title = "Lat vs Humidity"

linear(x,y,title,(45,20))
# Out:
# The r-value is: 0.1265437303854369

# %%
# Southern Hemisphere
x=southern_hemi_df["Lat"]
y=southern_hemi_df["Humidity"]
title = "Lat vs Humidity"

linear(x,y,title,(-25,30))
# Out:
# The r-value is: 0.2532904170716332

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x=northern_hemi_df["Lat"]
y=northern_hemi_df["Cloudiness"]
title = "Lat vs Cloudiness"

linear(x,y,title,(45,24))
# Out:
# The r-value is: 0.12193140878015582

# %%
# Southern Hemisphere
x=southern_hemi_df["Lat"]
y=southern_hemi_df["Cloudiness"]
title = "Lat vs Cloudiness"

linear(x,y,title,(-19,10))
# Out:
# The r-value is: 0.3217625674916504

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x=northern_hemi_df["Lat"]
y=northern_hemi_df["Wind Speed"]
title = "Lat vs Wind Speed"

linear(x,y,title,(10,12.3))
# Out:
# The r-value is: 0.0043342600958813345

# %%
# Southern Hemisphere
x=southern_hemi_df["Lat"]
y=southern_hemi_df["Wind Speed"]
title = "Lat vs Wind Speed"

linear(x,y,title,(-20,11))
# Out:
# The r-value is: 0.11981551443167453

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
